# %% [markdown]
# # Navier Stokes in a pipe flow (stationary 2D) with hard constraints

# %% [markdown]
# We solve the stationary Navier Stokes PDE:
#
# $$
# \begin{cases}
# \nabla\cdot\mathbf{u}=0,\\
# (\mathbf{u}\cdot\nabla)\mathbf{u} + \frac{1}{\rho}\nabla p - \theta \nabla^2\mathbf{u}=0.
# \end{cases}
# $$
#
# This becomes in 2D, with $\mathbf{u}=\begin{pmatrix}u_x \\ u_y\end{pmatrix}$
#
#
# $$
# \begin{cases}
# \frac{\partial}{\partial x} u_x + \frac{\partial}{\partial y} u_y = 0 \\
# \begin{pmatrix}u_x\frac{\partial}{\partial x} u_x + u_y\frac{\partial}{\partial y} u_x \\
# u_x\frac{\partial}{\partial x} u_y + u_y\frac{\partial}{\partial y} u_y  \end{pmatrix} +
# \frac{1}{\rho} \begin{pmatrix} \frac{\partial}{\partial x} p \\ \frac{\partial}{\partial y} p \end{pmatrix}
# - \theta
# \begin{pmatrix}
# \frac{\partial^2}{\partial x^2} u_x + \frac{\partial^2}{\partial y^2} u_x \\
# \frac{\partial^2}{\partial x^2} u_y + \frac{\partial^2}{\partial y^2} u_y
# \end{pmatrix} = 0\\
# \end{cases}
# $$
#
#
# With the boundary condition:
# $$
# \begin{cases}
# u(x, \frac{d}{2}) = -u(x, \frac{d}{2})=0, \forall x \text{ (boundary condition) }\\
# p(x_{min}, y)=0 \text{ and } p(x_{max}, y)=0.1, \forall y \text{ (boundary condition) }
# \end{cases}
# $$
#
# The domain is defined with $x\in[0,L]$ and $y\in[-R, R]$. __Note__ that because of the central symmetry with respect to the centerline of the tube, we only consider the $y$ axis which will represent the cross section
#
# This notebook aims at reproducing the exampleof section 3.1 of [*Surrogate modeling for fluid flows based on physics-constrained deep learning without simulation data*, Sun et al. 2020](https://www.sciencedirect.com/science/article/pii/S004578251930622X).

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %% [markdown]
# Import our package

# %%
import jinns

# %% [markdown]
# Import other dependencies

# %%
import jax
from jax import random, vmap
import jax.numpy as jnp
import equinox as eqx
import matplotlib.pyplot as plt

key = random.PRNGKey(2)

# %% [markdown]
# Create a DataGenerator object and set up some geometry. Following the [authors' implementation](https://github.com/Jianxun-Wang/LabelFree-DNN-Surrogate/blob/master/Tutorial/PipeFlow.ipynb), we set a pipe length $L=1$ and a pipe radius$R=0.05$. Following the authors, we also simplify the problem because of its geometry: the solution is symmetric with respect to the center of the pipe, at a given point $x\in[0, L]$. Therefore we only need one axis representing a pipe cross section and one axis representing the pipe length.

# %%
L = 1
R = 0.05

p_out = 0
p_in = 0.1

# %%
n = 10000
nb = None
omega_batch_size = 256
omega_border_batch_size = None
dim = 2
xmin = 0
xmax = xmin + L
ymin = -R
ymax = ymin + 2 * R
# zmin = -R
# zmax = zmin + 2 * R

method = "uniform"
key, subkey = random.split(key)
train_data = jinns.data.CubicMeshPDEStatio(
    key=subkey,
    n=n,
    nb=nb,
    omega_batch_size=omega_batch_size,
    omega_border_batch_size=omega_border_batch_size,
    dim=dim,
    min_pts=(xmin, ymin),
    max_pts=(xmax, ymax),
    method=method,
)

# %% [markdown]
# __Note:__ that we choose a very simple data generator and no boundary condition despite the pipe-like geometry. Indeed, we choose to follow the author's **hard coded boundary constraints**. The neural network outputs are then multiplied with a factor which enforces the constraints. We impose the so-called _slip-condition_ on the borders, ie, the fluid has a null speed on the borders.

# %% [markdown]
# Create the neural network architecture for the PINN with `equinox`. We have a PINN which outputs the velocity field `u` (2D output) and concatenated to the pressure field `p` (1D output). So the total PINN output is of size 3.
#
# The `output_transform` function enforces the *hardly* boundary conditions.

# %%
key, subkey = random.split(key)


def u_p_output_transform(pinn_in, pinn_out, params):
    return jnp.concatenate(
        [
            pinn_out[0:2] * (R**2 - pinn_in[1] ** 2),
            (pinn_in[0] - xmin) / (xmax - xmin) * p_out
            + (xmax - pinn_in[0]) / (xmax - xmin) * p_in
            + (xmin - pinn_in[0]) * (xmax - pinn_in[0]) * pinn_out[2:3],
        ],
        axis=-1,
    )


u_p, u_p_init_nn_params = jinns.nn.PPINN_MLP.create(
    key=subkey,
    eqx_list_list=[
        (
            (eqx.nn.Linear, 2, 25),
            (jax.nn.tanh,),
            (eqx.nn.Linear, 25, 25),
            (jax.nn.tanh,),
            (eqx.nn.Linear, 25, 25),
            (jax.nn.tanh,),
            (eqx.nn.Linear, 25, 2),
        ),
        (
            (eqx.nn.Linear, 2, 25),
            (jax.nn.tanh,),
            (eqx.nn.Linear, 25, 25),
            (jax.nn.tanh,),
            (eqx.nn.Linear, 25, 25),
            (jax.nn.tanh,),
            (eqx.nn.Linear, 25, 1),
        ),
    ],
    eq_type="PDEStatio",
    output_transform=u_p_output_transform,
)

# %% [markdown]
# ## Model parameters
# Here we set the density $\rho=1$ and we simplify the problem with respect to the article: $\theta$ is the viscosity parameter which we fix and feed as input to the PINN as done in the article; $\theta=0.00061$
#
# A set of parameters as required by the losses' `evaluate`. Here we adapt to the particular dynamic loss which requires the keys `u` and `p`.

# %%
rho = 1.0
nu = 0.00061

Delta_p = 0.1
d = 2 * R

# %%
init_params = jinns.parameters.Params(
    nn_params=u_p_init_nn_params,
    eq_params={"rho": rho, "nu": nu},
)

# %% [markdown]
# Plot the initial PINN outputs

# %%
nx, ny = 1000, 1000
val_xy_data = [jnp.linspace(xmin, xmax, nx), jnp.linspace(ymin, ymax, ny)]


u_xinit = lambda x: u_p(x, init_params)[0]
jinns.plot.plot2d(fun=u_xinit, xy_data=val_xy_data, title="u_init(x)")

u_yinit = lambda x: u_p(x, init_params)[1]
jinns.plot.plot2d(fun=u_yinit, xy_data=val_xy_data, title="u_init(y)")

# %%
jinns.plot.plot2d(
    fun=lambda x: u_p(x, init_params)[2], xy_data=val_xy_data, title="p(x, y)"
)

# %% [markdown]
# ## Analytical solution
# In this case, the analytical solution is known:
# $$
# u_a = \frac{\Delta p}{2\theta\rho L}(\frac{d^2}{4} - y^2)
# $$

# %%
def u_true(y):
    return Delta_p / (2 * nu * rho * L) * ((d / 2) ** 2 - y**2)


plt.plot(
    train_data.omega[:, 1].sort(axis=0),
    vmap(u_true, (0), 0)(train_data.omega[:, 1].sort(axis=0)),
)
plt.title(r"True solution along a cross section")
# Out:
# Text(0.5, 1.0, 'True solution along a cross section')

# %% [markdown]
# ## Observations

# %% [markdown]
# We create some noisy observations to illustrate this use-case in **jinns**. Note that the example is simple enough and observations are not needed to estimate the true solution. Note that we will only have observations for the velocity PINN $u$.

# %%
key, subkey = jax.random.split(key)
n_obs = 2500
x = jax.random.uniform(subkey, shape=(n_obs, 1), minval=(xmin), maxval=(xmax))
y = jax.random.uniform(subkey, shape=(n_obs, 1), minval=(ymin), maxval=(ymax))

obs = u_true(y)

obs_batch = jnp.concatenate([x, y, obs], axis=-1)

# %%
key, subkey = random.split(key)
obs_batch_size = omega_batch_size  # must be equal to time_batch_size !
obs_data = jinns.data.DataGeneratorObservations(
    obs_batch_size=omega_batch_size,
    observed_pinn_in=obs_batch[:, 0:2],
    observed_values=obs_batch[:, 2:3],
    key=subkey,
)

# %% [markdown]
# ## Loss construction

# %%
dyn_loss = jinns.loss.NavierStokesMassConservation2DStatio()

# %%
obs_data = None
loss_weights = jinns.loss.LossWeightsPDEStatio(
    dyn_loss=1.0, observations=1.0 if obs_data is not None else None
)

loss = jinns.loss.LossPDEStatio(
    u=u_p,
    loss_weights=loss_weights,
    dynamic_loss=dyn_loss,
    obs_slice=jnp.s_[0:1],  # we only observe the first slice
    params=init_params,
    boundary_condition=None,
)
# Out:
# /home/nicolas/Recherche/INRAE/PINN/jinns/jinns/loss/_LossPDE.py:138: UserWarning: Missing boundary condition.
#   warnings.warn("Missing boundary condition.")

# %%
# Testing the loss function
losses_and_grad = jax.value_and_grad(loss.evaluate, 0, has_aux=True)
train_data, data_batch = train_data.get_batch()
# obs_data, obs_batch = obs_data.get_batch()
losses, grads = losses_and_grad(
    init_params,
    batch=data_batch,  # jinns.data.append_obs_batch(data_batch, obs_batch)
)


l_tot, dict_losses = losses
print(f"total loss: {l_tot:.2f}")
print(
    f"Individual losses: { {key: f'{val[0]:.2f}' for key, val in dict_losses.items()} }"
)
# Out:
# total loss: 0.01
# Individual losses: {'dyn_loss': '0.01'}

# %%
r, g = loss.evaluate_with_natural_gradient(
    init_params,
    data_batch,
)

# %%
# Flatten the pytree of params gradient as a big (n, p) matrix
M = jinns.solver._utils._post_process_pytree_of_grad(g)

# Same for the loss values as a (n, 1) matrix
res = jnp.concatenate(
    jax.tree.leaves(r),
    axis=0,
)
# If we have only 1 dyn loss the line above is sufficient.
# However, we return a tuple of len (n_loss,) and we need to average
# over each loss (channels).
# TODO: should we account for loss_weights or not ?
res = res.mean(axis=1, keepdims=True)

euclidean_grad_array = jnp.mean(res * M, axis=0)

# Assemble Gram Matrix
n = M.shape[0]
gram_mat = (1 / n) * M.T @ M

# Solve the linear system Gx = eucl_grad
reg = 1e-5
n_param = gram_mat.shape[0]
natural_grad_array = jax.scipy.linalg.solve(
    gram_mat + reg * jnp.eye(n_param), euclidean_grad_array, assume_a="sym"
)

# %%
natural_grad_array.dot(euclidean_grad_array)
# Out:
# Array(0.00151367, dtype=float32)

# %%
# Final step : restructure the natural gradient as a nn_params PyTree
params = init_params
# natural_grads = jinns.solver._utils._nn_params_array_to_pytree(
#     natural_grad_array, params, params
# )
# euclidean_grads = _nn_params_array_to_pytree(
#     euclidean_grad_array, opt_params, params
# )

# %%
natural_grad_array.shape
# Out:
# (2828,)

# %% [markdown]
# ## Learning the neural network parameters
# The learning process here consider known equation parameters `eq_params`. We thus only update `nn_params`

# %%
params = init_params

# %%
import optax
from jinns.optimizers import vanilla_ngd

ngd_optim = optax.chain(
    optax.sgd(learning_rate=1.0),
    optax.scale_by_backtracking_linesearch(max_backtracking_steps=15, verbose=True),
)
tx = vanilla_ngd(ngd_optim)  # use jinns custom wrapper to tell `solve` to use ngd

# %%
params = init_params

# %%
n_iter = int(100)

# %%
params, total_loss_list, loss_by_term_dict, data, loss, _, _, _, _, _, _, _ = (
    jinns.solve(
        init_params=params,
        data=train_data,
        optimizer=tx,
        loss=loss,
        n_iter=n_iter,
        print_loss_every=n_iter // 10,
        # obs_data=obs_data,
    )
)
# Out:
# Initialization time: 2.292391300201416
#
# Compilation took
#  16.854037523269653
#
# [train] Iteration 0: loss value = 0.004380623809993267
# INFO: optax.scale_by_backtracking_linesearch:
# Backtracking linesearch failed to find a stepsize ensuring sufficent decrease.
# Value at current params: 0.0045310757122933865,
# Slope along update direction: -0.005522795021533966
# Stepsize: 0.021617282181978226
# Decrease Error: 2.8957443646504544e-05
# INFO: optax.scale_by_backtracking_linesearch:
# Backtracking linesearch failed to find a stepsize ensuring sufficent decrease.
# Value at current params: 0.004302769433706999,
# Slope along update direction: -0.004651844501495361
# Stepsize: 0.0011408858699724078
# Decrease Error: 1.8003115656028967e-06
# INFO: optax.scale_by_backtracking_linesearch:
# Backtracking linesearch failed to find a stepsize ensuring sufficent decrease.
# Value at current params: 0.004293977282941341,
# Slope along update direction: -0.004723180551081896
# Stepsize: 6.021204899298027e-05
# Decrease Error: 8.850408050875558e-08
# INFO: optax.scale_by_backtracking_linesearch:
# Backtracking linesearch failed to find a stepsize ensuring sufficent decrease.
# Value at current params: 0.004619653802365065,
# Slope along update direction: -0.005547237116843462
# Stepsize: 3.1777858566783834e-06
# Decrease Error: 4.192714175843548e-09
# INFO: optax.scale_by_backtracking_linesearch:
# Backtracking linesearch failed to find a stepsize ensuring sufficent decrease.
# Value at current params: 0.004395425785332918,
# Slope along update direction: -0.0045730434358119965
# Stepsize: 1.677126277854768e-07
# Decrease Error: 4.657380037187409e-10
# INFO: optax.scale_by_backtracking_linesearch:
# Backtracking linesearch failed to find a stepsize ensuring sufficent decrease.
# Value at current params: 0.004123447462916374,
# Slope along update direction: -0.004750462248921394
# Stepsize: 8.851296584566626e-09
# Decrease Error: 4.204774888189912e-15
# INFO: optax.scale_by_backtracking_linesearch:
# Backtracking linesearch failed to find a stepsize ensuring sufficent decrease.
# Value at current params: 0.004460558295249939,
# Slope along update direction: -0.00492494460195303
# Stepsize: 4.671410480661109e-10
# Decrease Error: 2.3006436580919423e-16
# INFO: optax.scale_by_backtracking_linesearch:
# Backtracking linesearch failed to find a stepsize ensuring sufficent decrease.
# Value at current params: 0.004352784715592861,
# Slope along update direction: -0.004737115930765867
# Stepsize: 2.4654103411569928e-11
# Decrease Error: 1.1678934117314758e-17
# INFO: optax.scale_by_backtracking_linesearch:
# Backtracking linesearch failed to find a stepsize ensuring sufficent decrease.
# Value at current params: 0.004431193694472313,
# Slope along update direction: -0.004765240475535393
# Stepsize: 1.3011591587161475e-12
# Decrease Error: 6.20033597461706e-19
# [train] Iteration 10: loss value = 0.004214025568217039
# INFO: optax.scale_by_backtracking_linesearch:
# Backtracking linesearch failed to find a stepsize ensuring sufficent decrease.
# Value at current params: 0.004214025568217039,
# Slope along update direction: -0.004931473173201084
# Stepsize: 6.86707296387e-14
# Decrease Error: 3.3864783971443756e-20
# INFO: optax.scale_by_backtracking_linesearch:
# Backtracking linesearch failed to find a stepsize ensuring sufficent decrease.
# Value at current params: 0.004259405191987753,
# Slope along update direction: -0.00483710877597332
# Stepsize: 3.624205800647606e-15
# Decrease Error: 1.753067742483535e-21
# INFO: optax.scale_by_backtracking_linesearch:
# Backtracking linesearch failed to find a stepsize ensuring sufficent decrease.
# Value at current params: 0.0042218915186822414,
# Slope along update direction: -0.004661013837903738
# Stepsize: 1.9127315526581366e-16
# Decrease Error: 8.915268606322021e-23
# INFO: optax.scale_by_backtracking_linesearch:
# Backtracking linesearch failed to find a stepsize ensuring sufficent decrease.
# Value at current params: 0.004416166804730892,
# Slope along update direction: -0.004777407739311457
# Stepsize: 1.0094742623571576e-17
# Decrease Error: 4.822670378493352e-24
# INFO: optax.scale_by_backtracking_linesearch:
# Backtracking linesearch failed to find a stepsize ensuring sufficent decrease.
# Value at current params: 0.004282111302018166,
# Slope along update direction: -0.004622455686330795
# Stepsize: 5.327658877409967e-19
# Decrease Error: 2.4626866815177167e-25
# INFO: optax.scale_by_backtracking_linesearch:
# Backtracking linesearch failed to find a stepsize ensuring sufficent decrease.
# Value at current params: 0.004039182793349028,
# Slope along update direction: -0.004369017668068409
# Stepsize: 2.8117555693645195e-20
# Decrease Error: 1.2284609631892093e-26
# INFO: optax.scale_by_backtracking_linesearch:
# Backtracking linesearch failed to find a stepsize ensuring sufficent decrease.
# Value at current params: 0.004396790638566017,
# Slope along update direction: -0.00531535129994154
# Stepsize: 1.4839482864294936e-21
# Decrease Error: 7.8877057910662e-28
# INFO: optax.scale_by_backtracking_linesearch:
# Backtracking linesearch failed to find a stepsize ensuring sufficent decrease.
# Value at current params: 0.004300798289477825,
# Slope along update direction: -0.004873692989349365
# Stepsize: 7.831770046267134e-23
# Decrease Error: 3.8169641446680517e-29
# INFO: optax.scale_by_backtracking_linesearch:
# Backtracking linesearch failed to find a stepsize ensuring sufficent decrease.
# Value at current params: 0.004282908048480749,
# Slope along update direction: -0.004694539122283459
# Stepsize: 4.133339659253623e-24
# Decrease Error: 1.9404124109475587e-30
# INFO: optax.scale_by_backtracking_linesearch:
# Backtracking linesearch failed to find a stepsize ensuring sufficent decrease.
# Value at current params: 0.004587152041494846,
# Slope along update direction: -0.005270869471132755
# Stepsize: 2.181435089055401e-25
# Decrease Error: 1.1498059201254628e-31
# [train] Iteration 20: loss value = 0.004364911466836929
# INFO: optax.scale_by_backtracking_linesearch:
# Backtracking linesearch failed to find a stepsize ensuring sufficent decrease.
# Value at current params: 0.004364911466836929,
# Slope along update direction: -0.004855537787079811
# Stepsize: 1.1512866392016795e-26
# Decrease Error: 5.590115547897206e-33
# INFO: optax.scale_by_backtracking_linesearch:
# Backtracking linesearch failed to find a stepsize ensuring sufficent decrease.
# Value at current params: 0.004269576631486416,
# Slope along update direction: -0.004575928673148155
# Stepsize: 6.07609664076536e-28
# Decrease Error: 2.7803781913119846e-34
# INFO: optax.scale_by_backtracking_linesearch:
# Backtracking linesearch failed to find a stepsize ensuring sufficent decrease.
# Value at current params: 0.004677386488765478,
# Slope along update direction: -0.005532912444323301
# Stepsize: 3.206755510353938e-29
# Decrease Error: 1.774269821378304e-35
# INFO: optax.scale_by_backtracking_linesearch:
# Backtracking linesearch failed to find a stepsize ensuring sufficent decrease.
# Value at current params: 0.004174993839114904,
# Slope along update direction: -0.004897225182503462
# Stepsize: 1.692415828686783e-30
# Decrease Error: 8.288140972624466e-37
# INFO: optax.scale_by_backtracking_linesearch:
# Backtracking linesearch failed to find a stepsize ensuring sufficent decrease.
# Value at current params: 0.004284330643713474,
# Slope along update direction: -0.004740053787827492
# Stepsize: 8.931992061481625e-32
# Decrease Error: 4.2338122744087075e-38
# INFO: optax.scale_by_backtracking_linesearch:
# Backtracking linesearch failed to find a stepsize ensuring sufficent decrease.
# Value at current params: 0.0044782510958611965,
# Slope along update direction: -0.005094726569950581
# Stepsize: 4.7140001391041696e-33
# Decrease Error: 2.4016546094400888e-39
# INFO: optax.scale_by_backtracking_linesearch:
# Backtracking linesearch failed to find a stepsize ensuring sufficent decrease.
# Value at current params: 0.004468950908631086,
# Slope along update direction: -0.004792709834873676
# Stepsize: 2.487887646178552e-34
# Decrease Error: 1.19237887627863e-40
# INFO: optax.scale_by_backtracking_linesearch:
# Backtracking linesearch failed to find a stepsize ensuring sufficent decrease.
# Value at current params: 0.004498217720538378,
# Slope along update direction: -0.004900005180388689
# Stepsize: 1.313021593642948e-35
# Decrease Error: 6.433361249715235e-42
# INFO: optax.scale_by_backtracking_linesearch:
# Backtracking linesearch failed to find a stepsize ensuring sufficent decrease.
# Value at current params: 0.0044281515292823315,
# Slope along update direction: -0.004954821430146694
# Stepsize: 6.929677848172639e-37
# Decrease Error: 3.433181237595802e-43
# INFO: optax.scale_by_backtracking_linesearch:
# Backtracking linesearch failed to find a stepsize ensuring sufficent decrease.
# Value at current params: 0.004096294287592173,
# Slope along update direction: -0.004474681802093983
# Stepsize: 3.6572463397041043e-38
# Decrease Error: 1.6815581571897805e-44
# [train] Iteration 30: loss value = 0.004114935174584389
# INFO: optax.scale_by_backtracking_linesearch:
# Backtracking linesearch failed to find a stepsize ensuring sufficent decrease.
# Value at current params: 0.004114935174584389,
# Slope along update direction: -0.004499894101172686
# Stepsize: 1.9301681229395036e-39
# Decrease Error: 1.401298464324817e-45
# [train] Iteration 40: loss value = 0.004317488521337509
# [train] Iteration 50: loss value = 0.004429468419402838
# [train] Iteration 60: loss value = 0.004449847619980574
# [train] Iteration 70: loss value = 0.004439802374690771
# [train] Iteration 80: loss value = 0.004260595887899399
# [train] Iteration 90: loss value = 0.004216781817376614
#
# Stopping main optimization loop, cause: max iteration is reached
#
# Training took
#  4.39776873588562
#
#
# Final iteration 100: train loss value = 0.0044137416407465935

# %% [markdown]
# ## Results

# %% [markdown]
# Plot the loss values

# %%
for loss_name, loss_values in loss_by_term_dict.items():
    plt.plot(jnp.log10(loss_values), label=loss_name)
plt.plot(jnp.log10(total_loss_list), label="total loss")
plt.legend()
plt.show();

# %% [markdown]
# Plot the ODE solutions learned by the PINN

# %%
jinns.plot.plot2d(
    fun=lambda x: u_p(x, params)[0], xy_data=val_xy_data, title="u_est, x(x ,y)"
)

jinns.plot.plot2d(
    fun=lambda x: u_p(x, params)[2], xy_data=val_xy_data, title="p_est(x, y)"
)

# %%
v_u_est_y = vmap(
    # compute average over array x with y_j fixed.
    lambda x, y_j: vmap(lambda z: u_p(jnp.stack([z, y_j], axis=-1), params)[0], 0, 0)(
        x
    ).mean(),
    (None, 0),
    0,
)


plt.plot(
    train_data.omega[::10, 1].sort(axis=0),
    v_u_est_y(
        train_data.omega[::10, 0].sort(axis=0), train_data.omega[::10, 1].sort(axis=0)
    ),
    "--",
    label="Estimated",
)
plt.plot(
    train_data.omega[::10, 1].sort(axis=0),
    vmap(u_true, (0), 0)(train_data.omega[::10, 1].sort(axis=0)),
    label="True",
    alpha=0.7,
)
plt.xlabel("y")
plt.ylabel(r"$\approx \int u(x, y) \, dx$")
plt.legend()
plt.title(r"True and estimated solutions along a cross section")
plt.show()

# %% [markdown]
# ## Conclusion
# As compared to other Navier-Stokes notebooks, it appears that guiding the optimization process with hard constraints and observations enhance the quality of the estimation solution.
